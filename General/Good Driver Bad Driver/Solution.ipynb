# %%
import pandas as pd

# %%
#importing data in dataset
df=pd.read_csv('drivertrainlabeled.csv')
df
# Out:
#        Driver_ID  Distance_Feature  Speeding_Feature Driving_Class
# 0     3423310448             53.76                 9       Average
# 1     3423310449             51.86                 4       Average
# 2     3423310450             51.59                 4       Average
# 3     3423310451            168.90                 5          Good
# 4     3423310452             53.50                 5       Average
# ...          ...               ...               ...           ...
# 3595  3423314442            140.25                92           Bad
# 3596  3423314443            156.38                 6          Good
# 3597  3423314444             51.59                 6       Average
# 3598  3423314445             51.73                 3       Average
# 3599  3423314447            201.12                19          Good
#
# [3600 rows x 4 columns]

# %%
df['Driving_Class'].replace({'Good':0, 'Average':1, 'Bad':2},inplace=True)
df.head(1)
# Out:
#     Driver_ID  Distance_Feature  Speeding_Feature  Driving_Class
# 0  3423310448             53.76                 9              1

# %%
#dividing dataframe into input and output values
dfinput= df.iloc[:,[1,2]]
dfoutput=df['Driving_Class']

# %%
#being the case of classification and both the input variables are numeric, we can go for KNN algo for creating model
from sklearn.neighbors import KNeighborsClassifier

# %%
#Task-1
#initailizing model
knn=KNeighborsClassifier()
#training model
knn.fit(dfinput,dfoutput)
#evaluting model
knn.score(dfinput,dfoutput)
# Out:
# 0.9997222222222222

# %%
#getting predicted values to get confusion matrix for future evalution if need, not mendatory
df['Pre_Driving_Class']=knn.predict(dfinput)
df.head()
# Out:
#     Driver_ID  Distance_Feature  Speeding_Feature  Driving_Class  \
# 0  3423310448             53.76                 9              1
# 1  3423310449             51.86                 4              1
# 2  3423310450             51.59                 4              1
# 3  3423310451            168.90                 5              0
# 4  3423310452             53.50                 5              1
#
#    Pre_Driving_Class
# 0                  1
# 1                  1
# 2                  1
# 3                  0
# 4                  1

# %%
actual=df['Driving_Class']
predicted=df['Pre_Driving_Class']

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(actual,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       625
#            1       1.00      1.00      1.00      2880
#            2       0.99      1.00      0.99        95
#
#     accuracy                           1.00      3600
#    macro avg       1.00      1.00      1.00      3600
# weighted avg       1.00      1.00      1.00      3600

# %%
#creating new dataframe for predicting values
df1=pd.read_csv('drivertestunlabeled.csv')
df1
# Out:
#       Driver_ID  Distance_Feature  Speeding_Feature  Driving_Class
# 0    3423310949             55.54                 5              1
# 1    3423313566             60.44                 3              1
# 2    3423310676             42.54                 3              1
# 3    3423313327            192.21                 8              0
# 4    3423311668             61.31                 4              1
# ..          ...               ...               ...            ...
# 395  3423313761            184.94                11              0
# 396  3423314396            165.23                57              2
# 397  3423314389             54.99                36              1
# 398  3423311270             63.20                 7              1
# 399  3423311238             48.66                 4              1
#
# [400 rows x 4 columns]

# %%
df1['Driving_Class']=knn.predict(df1.iloc[:,[1,2]])
df1
# Out:
#       Driver_ID  Distance_Feature  Speeding_Feature  Driving_Class
# 0    3423310949             55.54                 5              1
# 1    3423313566             60.44                 3              1
# 2    3423310676             42.54                 3              1
# 3    3423313327            192.21                 8              0
# 4    3423311668             61.31                 4              1
# ..          ...               ...               ...            ...
# 395  3423313761            184.94                11              0
# 396  3423314396            165.23                57              2
# 397  3423314389             54.99                36              1
# 398  3423311270             63.20                 7              1
# 399  3423311238             48.66                 4              1
#
# [400 rows x 4 columns]

# %%
df2 = pd.read_csv('drivertestlabeled.csv')
df2
# Out:
#       Driver_ID  Distance_Feature  Speeding_Feature  Driving_Class
# 0    3423310949             55.54                 5              1
# 1    3423313566             60.44                 3              1
# 2    3423310676             42.54                 3              1
# 3    3423313327            192.21                 8              0
# 4    3423311668             61.31                 4              1
# ..          ...               ...               ...            ...
# 395  3423313761            184.94                11              0
# 396  3423314396            165.23                57              2
# 397  3423314389             54.99                36              1
# 398  3423311270             63.20                 7              1
# 399  3423311238             48.66                 4              1
#
# [400 rows x 4 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(df2['Driving_Class'], df1['Driving_Class'])
print(accuracy)
# Out:
# 1.0

# %%
print(df2['Driving_Class'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 395    0
# 396    2
# 397    1
# 398    1
# 399    1
# Name: Driving_Class, Length: 400, dtype: int64

# %%
for i in df2['Driving_Class']:
    print(i, end="")
# Out:
# ...
